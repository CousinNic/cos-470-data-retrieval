# %%
import numpy as np
import matplotlib.pyplot as plt

#assign line 1 values
x1 = [0, .25, .5,  .5, .75, .75, 1]
y1 = [0, .25, .4, .25, .35, .3 , .4]

#assign line 2 values
x2 = [.25,.25, .5, .5, .75, .75, 1, 1]
y2 = [1,  .35, .5, .4, .5,  .35, .45, .4]

#label graph
fig, ax = plt.subplots()
ax.set(xlabel='recall', ylabel='precision')

#plot graph
plt.plot(x1,y1)
plt.plot(x2,y2)
